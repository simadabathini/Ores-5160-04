# %%
# importing the leading causes of death dataset into google colab
import pandas as pd
import numpy as np
file_path = r"LEADINGCAUSESOFDEATH.csv"
data = pd.read_csv(file_path)

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Columns: 236 entries, index to LCD_Time_Span
# dtypes: int64(232), object(4)
# memory usage: 5.7+ MB
# None
#              index  State_FIPS_Code  County_FIPS_Code  Strata_ID_Number  \
# count  3141.000000      3141.000000       3141.000000       3141.000000
# mean   1570.000000        30.304680        103.716651         44.696275
# std     906.872924        15.134423        107.999484         25.118434
# min       0.000000         1.000000          1.000000          1.000000
# 25%     785.000000        18.000000         35.000000         23.000000
# 50%    1570.000000        29.000000         79.000000         44.000000
# 75%    2355.000000        45.000000        133.000000         66.000000
# max    3140.000000        56.000000        840.000000         88.000000
#
#          A_Wh_Comp  CI_Min_A_Wh_Comp  CI_Max_A_Wh_Comp    A_Bl_Comp  \
# ...

# %%
# Example: Dropping columns 'CI_Min_A_Wh_Comp' and 'CHSI_State_Name'
data.drop(['CI_Min_A_Wh_Comp', 'CHSI_State_Name'], axis=1)
# Out:
#       index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name  \
# 0         0                1                 1          Autauga
# 1         1                1                 3          Baldwin
# 2         2                1                 5          Barbour
# 3         3                1                 7             Bibb
# 4         4                1                 9           Blount
# ...     ...              ...               ...              ...
# 3136   3136               56                37       Sweetwater
# 3137   3137               56                39            Teton
# 3138   3138               56                41            Uinta
# 3139   3139               56                43         Washakie
# 3140   3140               56                45           Weston
#
#      CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  CI_Max_A_Wh_Comp  \
# 0                 AL                29      -1111             -1111
# ...

# %%
data.dtypes
# Out:
# index                  int64
# State_FIPS_Code        int64
# County_FIPS_Code       int64
# CHSI_County_Name      object
# CHSI_State_Name       object
#                        ...
# CI_Max_F_Ot_Cancer     int64
# F_Hi_Cancer            int64
# CI_Min_F_Hi_Cancer     int64
# CI_Max_F_Hi_Cancer     int64
# LCD_Time_Span         object
# Length: 236, dtype: object

# %%
data['CHSI_County_Name'] = data['CHSI_County_Name'].astype(str)

# %%
data['CHSI_County_Name'].dtypes
# Out:
# dtype('O')

# %%
data ["test_column"] = np.random.rand(3141)
data.head()
# Out:
#    index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0      0                1                 1          Autauga         Alabama
# 1      1                1                 3          Baldwin         Alabama
# 2      2                1                 5          Barbour         Alabama
# 3      3                1                 7             Bibb         Alabama
# 4      4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  CI_Min_A_Wh_Comp  \
# 0              AL                29      -1111             -1111
# 1              AL                16         57                39
# 2              AL                51      -1111             -1111
# 3              AL                42      -1111             -1111
# 4              AL                28         34                17
#
#    CI_Max_A_Wh_Comp  ...  CI_Min_F_Bl_Cancer  CI_Max_F_Bl_Cancer  F_Ot_Cancer  \
# ...

# %%
data["test_column"].dtypes
# Out:
# dtype('float64')

# %%
data["test_column"] = pd.to_numeric(data["test_column"].round(0), downcast='integer')
data["test_column"].dtypes
# Out:
# dtype('int8')

# %%
print(data.test_column)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 3136    0
# 3137    0
# 3138    1
# 3139    0
# 3140    1
# Name: test_column, Length: 3141, dtype: int8

# %%
data1 =data[ data['CHSI_State_Name'] == 'Arkansas']
print(data1.shape)
data1.head()
# Out:
# (75, 237)
#      index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name  \
# 109    109                5                 1         Arkansas
# 110    110                5                 3           Ashley
# 111    111                5                 5           Baxter
# 112    112                5                 7           Benton
# 113    113                5                 9            Boone
#
#     CHSI_State_Name CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  \
# 109        Arkansas              AR                75      -1111
# 110        Arkansas              AR                68         27
# 111        Arkansas              AR                50      -1111
# 112        Arkansas              AR                13         36
# 113        Arkansas              AR                49      -1111
#
#      CI_Min_A_Wh_Comp  CI_Max_A_Wh_Comp  ...  CI_Min_F_Bl_Cancer  \
# 109             -1111             -1111  ...                  18
# ...

# %%
filter_criteria = (data['CHSI_State_Name'] == 'Arkansas') & (data['Strata_ID_Number'] >=20)
data1m =data[filter_criteria]
print(data1m.shape)
data1m.head()
# Out:
# (68, 237)
#      index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name  \
# 109    109                5                 1         Arkansas
# 110    110                5                 3           Ashley
# 111    111                5                 5           Baxter
# 113    113                5                 9            Boone
# 114    114                5                11          Bradley
#
#     CHSI_State_Name CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  \
# 109        Arkansas              AR                75      -1111
# 110        Arkansas              AR                68         27
# 111        Arkansas              AR                50      -1111
# 113        Arkansas              AR                49      -1111
# 114        Arkansas              AR                70      -1111
#
#      CI_Min_A_Wh_Comp  CI_Max_A_Wh_Comp  ...  CI_Min_F_Bl_Cancer  \
# 109             -1111             -1111  ...                  18
# ...

# %%
data [data.isnull().any(axis=1) ]
# Out:
# Empty DataFrame
# ...

# %%
data.rename(columns={'CHSI_State_Name':'state_name'})
# Out:
#       index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name state_name  \
# 0         0                1                 1          Autauga    Alabama
# 1         1                1                 3          Baldwin    Alabama
# 2         2                1                 5          Barbour    Alabama
# 3         3                1                 7             Bibb    Alabama
# 4         4                1                 9           Blount    Alabama
# ...     ...              ...               ...              ...        ...
# 3136   3136               56                37       Sweetwater    Wyoming
# 3137   3137               56                39            Teton    Wyoming
# 3138   3138               56                41            Uinta    Wyoming
# 3139   3139               56                43         Washakie    Wyoming
# 3140   3140               56                45           Weston    Wyoming
#
# ...

# %%
#Removing duplicate rows based on all columnsdata
data.drop_duplicates()
# Out:
#       index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name  \
# 0         0                1                 1          Autauga
# 1         1                1                 3          Baldwin
# 2         2                1                 5          Barbour
# 3         3                1                 7             Bibb
# 4         4                1                 9           Blount
# ...     ...              ...               ...              ...
# 3136   3136               56                37       Sweetwater
# 3137   3137               56                39            Teton
# 3138   3138               56                41            Uinta
# 3139   3139               56                43         Washakie
# 3140   3140               56                45           Weston
#
#      CHSI_State_Name CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  \
# 0            Alabama              AL                29      -1111
# ...

# %%
#Creating a new column 'Total' based on the sum of 'State_FIPS_Code' and 'Column5'
data['Total'] = data['State_FIPS_Code'] + data['County_FIPS_Code']
data.head()
# Out:
#    index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0      0                1                 1          Autauga         Alabama
# 1      1                1                 3          Baldwin         Alabama
# 2      2                1                 5          Barbour         Alabama
# 3      3                1                 7             Bibb         Alabama
# 4      4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  CI_Min_A_Wh_Comp  \
# 0              AL                29      -1111             -1111
# 1              AL                16         57                39
# 2              AL                51      -1111             -1111
# 3              AL                42      -1111             -1111
# 4              AL                28         34                17
#
#    CI_Max_A_Wh_Comp  ...  CI_Max_F_Bl_Cancer  F_Ot_Cancer  CI_Min_F_Ot_Cancer  \
# ...

# %%
# Capping outliers
percentileq99 = data['A_Wh_Comp'].quantile(0.99)
data['A_Wh_Comp'] = data['A_Wh_Comp'].clip(upper=30)
data.head()
# Out:
#    index  State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0      0                1                 1          Autauga         Alabama
# 1      1                1                 3          Baldwin         Alabama
# 2      2                1                 5          Barbour         Alabama
# 3      3                1                 7             Bibb         Alabama
# 4      4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  CI_Min_A_Wh_Comp  \
# 0              AL                29      -1111             -1111
# 1              AL                16         30                39
# 2              AL                51      -1111             -1111
# 3              AL                42      -1111             -1111
# 4              AL                28         30                17
#
#    CI_Max_A_Wh_Comp  ...  CI_Max_F_Bl_Cancer  F_Ot_Cancer  CI_Min_F_Ot_Cancer  \
# ...

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Columns: 238 entries, index to Total
# dtypes: int64(233), int8(1), object(4)
# memory usage: 5.7+ MB
# None
#              index  State_FIPS_Code  County_FIPS_Code  Strata_ID_Number  \
# count  3141.000000      3141.000000       3141.000000       3141.000000
# mean   1570.000000        30.304680        103.716651         44.696275
# std     906.872924        15.134423        107.999484         25.118434
# min       0.000000         1.000000          1.000000          1.000000
# 25%     785.000000        18.000000         35.000000         23.000000
# 50%    1570.000000        29.000000         79.000000         44.000000
# 75%    2355.000000        45.000000        133.000000         66.000000
# max    3140.000000        56.000000        840.000000         88.000000
#
#          A_Wh_Comp  CI_Min_A_Wh_Comp  CI_Max_A_Wh_Comp    A_Bl_Comp  \
# ...

# %%
# cleaned dataset.
data.to_csv("cleaned_dataset.csv", index=False)
